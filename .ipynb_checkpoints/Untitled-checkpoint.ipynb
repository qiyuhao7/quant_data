# %%
import akshare as ak

# %%
fund_open_fund_daily_em_df = ak.fund_open_fund_daily_em()
print(fund_open_fund_daily_em_df)
# Out:
# /home/qiyuhao7/miniconda3/lib/python3.10/site-packages/akshare/__init__.py:2831: UserWarning: 为了支持更多特性，请将 Pandas 升级到 2.2.0 及以上版本！
#   warnings.warn(
#          基金代码                  基金简称 2024-09-26-单位净值 2024-09-26-累计净值  \
# 0      007674             工银产业升级股票A          1.0211          1.0211
# 1      007675             工银产业升级股票C          0.9833          0.9833
# 2      010745             工银灵动价值混合C          0.6831          0.6831
# 3      010744             工银灵动价值混合A          0.6961          0.6961
# 4      013342             工银核心机遇混合C          0.6093          0.6093
# ...       ...                   ...             ...             ...
# 19595  020559             工银健康产业混合C
# 19596  021645  东方红欣悦稳健3个月持有混合(FOF)A
# 19597  021646  东方红欣悦稳健3个月持有混合(FOF)C
# 19598  020822             大成领先动力混合C
# 19599  022182  招商智星稳健配置混合(FOF-LOF)D
#
#       2024-09-25-单位净值 2024-09-25-累计净值    日增长值   日增长率  申购状态  赎回状态    手续费
# 0              0.9137          0.9137  0.1074  11.75  开放申购  开放赎回  0.15%
# ...

# %%
fund_open_fund_daily_em_df[
# Out:
#          基金代码                  基金简称 2024-09-26-单位净值 2024-09-26-累计净值  \
# 0      007674             工银产业升级股票A          1.0211          1.0211
# 1      007675             工银产业升级股票C          0.9833          0.9833
# 2      010745             工银灵动价值混合C          0.6831          0.6831
# 3      010744             工银灵动价值混合A          0.6961          0.6961
# 4      013342             工银核心机遇混合C          0.6093          0.6093
# ...       ...                   ...             ...             ...
# 19595  020559             工银健康产业混合C
# 19596  021645  东方红欣悦稳健3个月持有混合(FOF)A
# 19597  021646  东方红欣悦稳健3个月持有混合(FOF)C
# 19598  020822             大成领先动力混合C
# 19599  022182  招商智星稳健配置混合(FOF-LOF)D
#
#       2024-09-25-单位净值 2024-09-25-累计净值    日增长值   日增长率  申购状态  赎回状态    手续费
# 0              0.9137          0.9137  0.1074  11.75  开放申购  开放赎回  0.15%
# 1              0.8799          0.8799  0.1034  11.75  开放申购  开放赎回  0.00%
# 2              0.6137          0.6137  0.0694  11.31  开放申购  开放赎回  0.00%
# ...

# %%
fund_info_index_em_df = ak.fund_info_index_em(symbol="沪深指数", indicator="增强指数型")

# %%
fund_info_index_em_df
# Out:
#        基金代码                 基金名称    单位净值          日期  日增长率    近1周   近1月   近3月  \
# 0    010736        易方达沪深300指数增强A  0.7387  2024-09-26  5.26  11.55  6.93  0.72
# 1    010737        易方达沪深300指数增强C  0.7298  2024-09-26  5.26  11.56  6.91  0.65
# 2    012157      汇添富上证50基本面增强指数A  0.8694  2024-09-26  3.03   8.26  3.95  2.04
# 3    012158      汇添富上证50基本面增强指数C  0.8594  2024-09-26  3.03   8.25  3.91  1.93
# 4    510080          长盛全债指数增强债券A  1.6158  2024-09-26  0.15   0.56  1.30  0.57
# ..      ...                  ...     ...         ...   ...    ...   ...   ...
# 434  021185       中信保诚中证500指数增强A  1.0230  2024-09-26  4.02   8.61  7.76  2.30
# 435  021186       中信保诚中证500指数增强C  1.0219  2024-09-26  4.01   8.60  7.73  2.19
# 436  021848  国泰沪深300增强策略ETF发起联接C  0.9998  2024-09-20   NaN  -0.01   NaN   NaN
# 437  021170         大成中证500指数增强A  1.0100  2024-09-26  3.40   7.22  4.84   NaN
# 438  021171         大成中证500指数增强C  1.0093  2024-09-26  3.39   7.20  4.80   NaN
#
# ...

# %%
fund_exchange_rank_em_df = ak.fund_exchange_rank_em()

# %%
fund_exchange_rank_em_df
# Out:
#       序号    基金代码                 基金简称        类型          日期    单位净值    累计净值  \
# 0      1  159509  景顺长城纳斯达克科技ETF(QDII)  指数型-海外股票  2024-09-25  1.3816  1.3816
# 1      2  513390   博时纳斯达克100ETF(QDII)  指数型-海外股票  2024-09-25  1.5739  1.5739
# 2      3  159696  易方达纳斯达克100ETF(QDII)  指数型-海外股票  2024-09-25  1.3036  1.3036
# 3      4  159660        汇添富纳斯达克100ETF  指数型-海外股票  2024-09-25  1.5351  1.5351
# 4      5  513100         国泰纳斯达克100ETF  指数型-海外股票  2024-09-25  1.4130  7.0650
# ..   ...     ...                  ...       ...         ...     ...     ...
# 963  964  520660     南方中证国新港股通央企红利ETF    指数型-股票  2024-09-26  0.8941  0.8941
# 964  965  520990   景顺长城中证国新港股通央企红利ETF    指数型-股票  2024-09-26  0.8932  0.8932
# 965  966  560620        万家中证全指公用事业ETF    指数型-股票  2024-09-20  0.9999  0.9999
# 966  967  159333       万家中证港股通央企红利ETF    指数型-股票  2024-09-26  1.0573  1.0573
# 967  968  159302         银华中证港股高股息ETF    指数型-股票  2024-09-26  1.0491  1.0491
#
# ...

# %%
fund_scale_open_sina_df = ak.fund_scale_open_sina(symbol='股票型基金')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fund_scale_open_sina_df = ak.fund_scale_open_sina(symbol='股票型基金')
#
# File ~/miniconda3/lib/python3.10/site-packages/akshare/fund/fund_scale_sina.py:70, in fund_scale_open_sina(symbol)
#      45 temp_df["index"] = range(1, len(temp_df) + 1)
#      46 temp_df.rename(
#      47     columns={
#      48         "index": "序号",
#    (...)
#      68     inplace=True,
#      69 )
# ---> 70 temp_df = temp_df[
#      71     [
#      72         "序号",
#      73         "基金代码",
#      74         "基金简称",
#      75         "单位净值",
#      76         "总募集规模",
#      77         "最近总份额",
#      78         "成立日期",
#      79         "基金经理",
#      80         "更新日期",
#      81     ]
#      82 ]
#      83 temp_df["成立日期"] = pd.to_datetime(temp_df["成立日期"], errors="coerce").dt.date
# ...

# %%
fund_etf_spot_em_df = ak.fund_etf_spot_em()

# %%
fund_etf_spot_em_df
# Out:
#          代码          名称    最新价  IOPV实时估值  基金折价率    涨跌额    涨跌幅        成交量  \
# 0    588500  科创100ETF增强  1.035    0.9688  -6.83  0.109  11.77     8364.0
# 1    159745       建材ETF  0.545    0.5295  -2.93  0.050  10.10   912890.0
# 2    515710       食品ETF  0.591    0.5857  -0.90  0.054  10.06   833495.0
# 3    515170     食品饮料ETF  0.559    0.5509  -1.47  0.051  10.04  2845826.0
# 4    159931       金融ETF  1.713    1.6252  -5.40  0.156  10.02    30558.0
# ..      ...         ...    ...       ...    ...    ...    ...        ...
# 953  159502   标普生物科技ETF  1.035    1.0271  -0.77 -0.004  -0.38   942511.0
# 954  518860     黄金ETFAU  5.772    5.7688  -0.06 -0.033  -0.57     4093.0
# 955  513290   纳指生物科技ETF  1.214    1.2025  -0.96 -0.007  -0.57  1309864.0
# 956  159518     标普油气ETF  0.902    0.9007  -0.14 -0.019  -2.06   471984.0
# 957  513350     标普油气ETF  0.936    0.9413   0.56 -0.023  -2.40   429378.0
#
#              成交额    开盘价  ...    小单净流入-净额  小单净流入-净占比       现手     买一     卖一  \
# ...

# %%
threshold = fund_etf_spot_em_df['总市值'].quantile(0.7)

# 筛选出总市值大于等于 30% 分位数的行
fund_etf_spot_em_df_split = fund_etf_spot_em_df[fund_etf_spot_em_df['总市值'] >= threshold]

# 如果你只想要前 30% 的行
top_30_percent_df = fund_etf_spot_em_df.nlargest(int(len(fund_etf_spot_em_df) * 0.3), '总市值')

# %%
fund_etf_spot_em_df_split
# Out:
#          代码            名称     最新价  IOPV实时估值  基金折价率    涨跌额    涨跌幅        成交量  \
# 2    515710         食品ETF   0.591    0.5857  -0.90  0.054  10.06   833495.0
# 3    515170       食品饮料ETF   0.559    0.5509  -1.47  0.051  10.04  2845826.0
# 6    512200        房地产ETF   1.395    1.3683  -1.95  0.127  10.02  4911019.0
# 10   159736         饮食ETF   0.673    0.6626  -1.57  0.061   9.97   369216.0
# 15   159928         消费ETF   0.785    0.7696  -2.00  0.071   9.94  6906529.0
# ..      ...           ...     ...       ...    ...    ...    ...        ...
# 950  511990       华宝添益ETF  99.938       NaN    NaN -0.042  -0.04  1990677.0
# 951  520900       红利ETF港股   0.899    0.8938  -0.58 -0.001  -0.11   796156.0
# 952  520660  港股通央企红利ETF南方   0.896    0.8917  -0.48 -0.001  -0.11   446490.0
# 953  159502     标普生物科技ETF   1.035    1.0271  -0.77 -0.004  -0.38   942511.0
# 955  513290     纳指生物科技ETF   1.214    1.2025  -0.96 -0.007  -0.57  1309864.0
#
# ...

# %%
top_30_percent_df
# Out:
#          代码           名称    最新价  IOPV实时估值  基金折价率    涨跌额    涨跌幅         成交量  \
# 189  510300     沪深300ETF  3.640    3.6170  -0.64  0.166   4.78  44429621.0
# 193  510310  沪深300ETF易方达  3.564    3.5438  -0.57  0.162   4.76  11492600.0
# 177  510330   沪深300ETF华夏  3.723    3.7008  -0.60  0.172   4.84   3759204.0
# 96   510050      上证50ETF  2.618    2.5957  -0.86  0.138   5.56  23766597.0
# 211  159919     沪深300ETF  3.726    3.7100  -0.43  0.167   4.69   6184645.0
# ..      ...          ...    ...       ...    ...    ...    ...         ...
# 2    515710        食品ETF  0.591    0.5857  -0.90  0.054  10.06    833495.0
# 136  159867        畜牧ETF  0.539    0.5404   0.26  0.026   5.07    742758.0
# 732  516090    新能源ETF易方达  0.335    0.3348  -0.06  0.010   3.08   1043963.0
# 151  515230        软件ETF  0.570    0.5677  -0.41  0.027   4.97   1105111.0
# 315  510590   中证500ETF平安  5.143    5.1162  -0.52  0.214   4.34     29064.0
#
# ...

# %%
top_30_percent_df.to_csv("fund_f30.csv")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/qiyuhao7/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2861/34463322.py", line 1, in <module>
#     top_30_percent_df.to_csv("fund_f30.csv")
#   File "/home/qiyuhao7/miniconda3/lib/python3.10/site-packages/pandas/core/generic.py", line 3466, in to_csv
#     .. versionchanged:: 2.0.0
#   File "/home/qiyuhao7/miniconda3/lib/python3.10/site-packages/pandas/io/formats/format.py", line 1078, in to_csv
#   File "/home/qiyuhao7/miniconda3/lib/python3.10/site-packages/pandas/io/formats/csvs.py", line 24, in <module>
#     from pandas._typing import SequenceNotStr
# ImportError: cannot import name 'SequenceNotStr' from 'pandas._typing' (/home/qiyuhao7/miniconda3/lib/python3.10/site-packages/pandas/_typing.py)
#
# ...
