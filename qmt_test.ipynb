# %%
from xtquant import xtdata

# 获取板块列表
print( xtdata.get_sector_list())
# Out:
# ***** xtdata连接成功 *****
# 服务信息: {'tag': 'sp3', 'version': '1.0'}
# 服务地址: 127.0.0.1:58610
# 数据路径: C:\国金证券QMT交易端\bin.x64/../userdata_mini/datadir
# 设置xtdata.enable_hello = False可隐藏此消息
#
# ['上期所', '上证A股', '上证B股', '上证期权', '上证转债', '中金所', '创业板', '大商所', '沪市ETF', '沪市债券', '沪市基金', '沪市指数', '沪深A股', '沪深B股', '沪深ETF', '沪深债券', '沪深基金', '沪深指数', '沪深转债', '深市ETF', '深市债券', '深市基金', '深市指数', '深证A股', '深证B股', '深证期权', '深证转债', '科创板', '科创板CDR', '能源中心', '连续合约', '郑商所', '香港联交所指数', '香港联交所股票']

# %%
xtdata.download_history_data(
    stock_code="159995.SZ",
    period="1d",
    start_time="20000101",
    end_time="20241231"
)

# %%
data = xtdata.get_local_data(
    stock_list=["159995.SZ"],  # 股票代码
    period="1d",            # 日线数据
    start_time="20000101",  # 起始日期
    end_time="20241231"     # 结束日期
)

# %%
data['159995.SZ']
# Out:
#                    time   open   high    low  close    volume        amount  \
# 20200210  1581264000000  1.048  1.048  1.010  1.027   9955870  1.023969e+09
# 20200211  1581350400000  1.029  1.048  1.025  1.037   7112839  7.376885e+08
# 20200212  1581436800000  1.033  1.073  1.030  1.068   8087915  8.521658e+08
# 20200213  1581523200000  1.071  1.125  1.068  1.099  12825099  1.407997e+09
# 20200214  1581609600000  1.107  1.140  1.081  1.103  16690538  1.852287e+09
# ...                 ...    ...    ...    ...    ...       ...           ...
# 20241225  1735056000000  1.257  1.278  1.253  1.261   6805735  8.618855e+08
# 20241226  1735142400000  1.257  1.285  1.251  1.281   7207969  9.173894e+08
# 20241227  1735228800000  1.280  1.305  1.267  1.271   8820911  1.133798e+09
# 20241230  1735488000000  1.269  1.294  1.262  1.276   6614339  8.443505e+08
# 20241231  1735574400000  1.276  1.280  1.226  1.226   6023573  7.512347e+08
#
# ...

# %%
type(data['159995.SZ'])
# Out:
# pandas.core.frame.DataFrame
