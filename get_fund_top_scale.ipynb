# %%
import akshare as ak

# %%
fund_etf_spot_em_df = ak.fund_etf_spot_em()

# %%
top_30p_etf = fund_etf_spot_em_df.nlargest(int(len(fund_etf_spot_em_df) * 0.3), '总市值')

# %%
top_30p_etf.to_csv("etf_top30p.csv")

# %%
fund_lof_spot_em_df = ak.fund_lof_spot_em()

# %%
top_30p_lof = fund_lof_spot_em_df.nlargest(int(len(fund_lof_spot_em_df) * 0.3), '总市值')

# %%
top_30p_lof
# Out:
#          代码         名称    最新价    涨跌额   涨跌幅       成交量           成交额    开盘价  \
# 120  501208  中欧创新未来LOF  0.713  0.035  5.16    9571.0  6.738500e+05  0.680
# 145  501203  易基创新未来LOF  0.778  0.035  4.71    8215.0  6.250940e+05  0.748
# 137  501206  添富创新未来LOF  0.535  0.025  4.90    6643.0  3.498030e+05  0.515
# 60   501207  华夏创新未来LOF  0.490  0.032  6.99   23242.0  1.118529e+06  0.460
# 109  163417    兴全合宜LOF  1.299  0.066  5.35  307810.0  3.942349e+07  1.250
# ..      ...        ...    ...    ...   ...       ...           ...    ...
# 377  161126  标普医疗保健LOF  1.950 -0.019 -0.96   11107.0  2.163946e+06  1.960
# 177  501043   沪深300LOF  1.242  0.048  4.02   14683.0  1.802660e+06  1.202
# 110  160142  南方优势产业LOF  0.887  0.045  5.34    2452.0  2.140308e+05  0.856
# 191  501081    科创中欧LOF  1.337  0.049  3.80    2147.0  2.866040e+05  1.292
# 123  160611  鹏华优质治理LOF  0.860  0.042  5.13     455.0  3.902922e+04  0.833
#
#        最高价    最低价     昨收   换手率        流通市值         总市值
# ...

# %%
top_30p_lof.to_csv("lof_top30p.csv")
